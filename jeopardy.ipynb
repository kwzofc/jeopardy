# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\kwzof\AppData\Local\Temp/ipykernel_14332/3652881321.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# Read CSV File And Rename Columns
all_data = pd.read_csv('jeopardy.csv').dropna(how='all').rename(columns={
    'Show Number': 'show_number',
    ' Air Date': 'air_date',
    ' Round': 'round',
    ' Category': 'category',
    ' Value': 'value',
    ' Question': 'question',
    ' Answer': 'answer'
})

# %%
all_data
# Out:
#         show_number    air_date             round  \
# 0       4680         2004-12-31  Jeopardy!
# 1       4680         2004-12-31  Jeopardy!
# 2       4680         2004-12-31  Jeopardy!
# 3       4680         2004-12-31  Jeopardy!
# 4       4680         2004-12-31  Jeopardy!
# ...      ...                ...        ...
# 216925  4999         2006-05-11  Double Jeopardy!
# 216926  4999         2006-05-11  Double Jeopardy!
# 216927  4999         2006-05-11  Double Jeopardy!
# 216928  4999         2006-05-11  Double Jeopardy!
# 216929  4999         2006-05-11  Final Jeopardy!
#
#                                category  value  \
# 0       HISTORY                          $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2       EVERYBODY TALKS ABOUT IT...      $200
# 3       THE COMPANY LINE                 $200
# 4       EPITAPHS & TRIBUTES              $200
# ...                     ...               ...
# 216925  RIDDLE ME THIS                   $2000
# ...

# %%
# Search Function
def search(stringset):
    result = all_data
    for string in stringset:
        result = result[result.question.str.contains(string, case=False, regex=True)]
    return result

# %%
search(['King', 'England'])
# Out:
#         show_number    air_date             round               category  \
# 4953    3003         1997-09-24  Double Jeopardy!  "PH"UN WORDS
# 6337    3517         1999-12-14  Double Jeopardy!  Y1K
# 9191    3907         2001-09-04  Double Jeopardy!  WON THE BATTLE
# 11710   2903         1997-03-26  Double Jeopardy!  BRITISH MONARCHS
# 13454   4726         2005-03-07  Jeopardy!         A NUMBER FROM 1 TO 10
# ...      ...                ...        ...                           ...
# 208295  4621         2004-10-11  Jeopardy!         THE VIKINGS
# 208742  4863         2005-11-02  Double Jeopardy!  BEFORE & AFTER
# 213870  5856         2010-02-15  Double Jeopardy!  URANUS
# 216021  1881         1992-11-09  Double Jeopardy!  HISTORIC NAMES
# 216789  5070         2006-09-29  Double Jeopardy!  ANCIENT HISTORY
#
#          value  \
# 4953    $200
# 6337    $800
# 9191    $800
# 11710   $600
# 13454   $1000
# ...       ...
# 208295  $600
# 208742  $3,000
# 213870  $1600
# 216021  $1000
# ...

# %%
#Add new column of value
all_data['float_value'] = all_data.apply(lambda row: row.value[1:].replace(',', '') if row.value != 'None' else 0.0, axis=1)

# %%
all_data
# Out:
#         show_number    air_date             round  \
# 0       4680         2004-12-31  Jeopardy!
# 1       4680         2004-12-31  Jeopardy!
# 2       4680         2004-12-31  Jeopardy!
# 3       4680         2004-12-31  Jeopardy!
# 4       4680         2004-12-31  Jeopardy!
# ...      ...                ...        ...
# 216925  4999         2006-05-11  Double Jeopardy!
# 216926  4999         2006-05-11  Double Jeopardy!
# 216927  4999         2006-05-11  Double Jeopardy!
# 216928  4999         2006-05-11  Double Jeopardy!
# 216929  4999         2006-05-11  Final Jeopardy!
#
#                                category  value  \
# 0       HISTORY                          $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2       EVERYBODY TALKS ABOUT IT...      $200
# 3       THE COMPANY LINE                 $200
# 4       EPITAPHS & TRIBUTES              $200
# ...                     ...               ...
# 216925  RIDDLE ME THIS                   $2000
# ...

# %%
# Change data type to float
all_data['float_value'] = pd.to_numeric(all_data['float_value'])

# %%
all_data
# Out:
#         show_number    air_date             round  \
# 0       4680         2004-12-31  Jeopardy!
# 1       4680         2004-12-31  Jeopardy!
# 2       4680         2004-12-31  Jeopardy!
# 3       4680         2004-12-31  Jeopardy!
# 4       4680         2004-12-31  Jeopardy!
# ...      ...                ...        ...
# 216925  4999         2006-05-11  Double Jeopardy!
# 216926  4999         2006-05-11  Double Jeopardy!
# 216927  4999         2006-05-11  Double Jeopardy!
# 216928  4999         2006-05-11  Double Jeopardy!
# 216929  4999         2006-05-11  Final Jeopardy!
#
#                                category  value  \
# 0       HISTORY                          $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2       EVERYBODY TALKS ABOUT IT...      $200
# 3       THE COMPANY LINE                 $200
# 4       EPITAPHS & TRIBUTES              $200
# ...                     ...               ...
# 216925  RIDDLE ME THIS                   $2000
# ...

# %%
# Average Value of Questions That Contain The Word "King"
average_values_of_king_word = search(['King']).float_value.mean()
print('Average question values is ${}'.format(round(average_values_of_king_word, 2)))
# Out:
# Average question values is $771.88

# %%
# Function that returns the count of the unique answers to all of the questions in a dataset.
def unique_answer(search):
    question = search
    result = question.answer.nunique()
    return result

# %%
# Filtering the entire dataset to only questions containing the word "King" and count all of the unique answers in dataset.
king_word_unique_answer = unique_answer(search(['King']))
print(f'Total answers: {king_word_unique_answer}')
# Out:
# Total answers: 5268
